# %% [markdown]
# # **Project Name**    -
#
# Zomato Customer Review Sentiment Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# I Built an NLP-based sentiment classification model using TF-IDF and Logistic Regression to analyze Zomato customer reviews. Performed EDA, feature engineering, and hyperparameter tuning using GridSearchCV, achieving 92% accuracy. Deployed the trained model using Streamlit for real-time prediction.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Ashishchandra7/Zomato-sentiment-analysis
#
#
# https://zomato-sentiment-analysis-tzfgfnfjftwupawgwjtnsq.streamlit.app/

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Zomato receives thousands of customer reviews daily. Manually analyzing them is difficult. The goal is to build a machine learning model that automatically classifies reviews as Positive, Neutral, or Negative.
# 1.Understand whether customer reviews are positive, negative, or neutral.
# 2.cluster the zomato restaurants into different segments
# 3.cuisine and costing can be used in cost vs benefit analysis
# 4.help customers finding the Best restaurant in their locality

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df1=pd.read_csv('/content/sample_data/Zomato Restaurant names and Metadata.csv')
df2=pd.read_csv('/content/sample_data/Zomato Restaurant reviews.csv')
df = pd.merge(df1, df2, left_on="Name", right_on="Restaurant", how="inner")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(5)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
sns.heatmap(df.isnull())

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In our dataset we have 10000 rows and 13 columns,36 duplicated values and too many null values in collections columns and less null values in other columns

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# In our dataset we 12 object type and 1 integer type and most of the columns has null values.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()

# %%
df.rename(columns={'Collections':'Location'},inplace=True)
df['Location'].fillna(df['Location'].mode()[0],inplace=True)
df['Review'].fillna(df['Review'].mode()[0],inplace=True)
df['review_length'] = df['Review'].apply(lambda x: len(str(x)))
df.head(3)

# %%
df.drop(columns={'Name','Links','Timings','Time'},inplace=True)

# %%
df['Cost'].tail(3)

# %%
df['Cost']=df['Cost'].str.replace(',','').astype(int)

# %%
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

#errors='coerce' converts invalid values to NaN

# %%
df['reviews'] = df['Metadata'].str.extract('(\d+)\s*Review').fillna(0).astype(int)
df['followers'] = df['Metadata'].str.extract('(\d+)\s*Followers').fillna(0).astype(int)

# %%
df.shape

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1.First removed duplicate rows
# 2.Rename the collections column to Location
# 3.Then fill the null values will mean meadian and mode
# 4.Then drop unnecessary columns
# 5.change datatype of some columns
# 6.then extracted reviews and followers from metadata
# 7.now we have 9761 rows and 11 columns after the data wrangling

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
sns.histplot(df['Rating'],bins=10)
plt.title('Distribution of rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected histogram plot for understanding the numerical distribution data for customer rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the restaurant rating is between 4 to 5.Average rating restaurant are below 3.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes if restaurant is having rating above 4 more number of customer will attract and may sail increses
#
# yes if restaurant is having less rating 1 or 2 customer will reject and buisness maybe get slow.
#
# zomato can promote highly rated restaurant to improve customer trust and engagement

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
sns.histplot(df['Cost'],bins=20)
plt.title('Distribution of cost')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected histogram plot for understanding the numerical data distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the restaurant price range is between 500 to 1500 so the most
# the restaurant make their price range in between.High cost restaurant is above 1500.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes this insight may help new resaturant entering into the market to set their price range in between to be in the market.
#
# yes restaurant above 1500 price are in less demand should give some offers or complimentary to attract the customer.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
df.groupby('Restaurant')['Rating'].mean().sort_values(ascending=False).head(5).plot(kind='bar')
plt.title('Average Rating per Restaurant')
plt.xlabel('Restaurant')
plt.ylabel('Average Rating')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used bar chart for compare the categories and values of restaurant and rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Absolute barbecue has the highest average rating than others restaurant.Others Restaurant also has highest rating close to 4.6-4.8

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes Zomato can highlight or recommend these restaurant to the customers.
#
# yes restaurant with less rating may lose customers.restaurant need to give Quality and good services to the customer to increase the rating.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
df.groupby('Restaurant')['reviews'].mean().sort_values(ascending=False).head(5).plot(kind='bar')
plt.title('Average Reviews per Restaurant')
plt.xlabel('Restaurant')
plt.ylabel('Average Reviews')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used bar chart for compare the categories and values of restaurant and rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Restaurnt Labonel has the highest average number of reviews,indicates strong customer engagement and popularity.others Resataurant also has significant number of reviews

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Restaurants with more Reviews are trusted by customers.
# Zomato can highlight or recommend  these popular restaurant to users.4

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(5,4))
df['Location'].value_counts().head(5).plot(kind='bar')
plt.title("Top 5 Locations with Most Restaurants")
plt.xlabel("Location")
plt.ylabel("Number of Restaurants")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
df.groupby('Restaurant')['Cost'].mean().sort_values(ascending=False).head(5).plot(kind='bar')
plt.title('Average Cost per Restaurant')
plt.xlabel('Restaurant')
plt.ylabel('Average Cost')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I use bar chart to compare the numerical values of categories.to visualise the higher and lower average resataurant cost.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# College Gachibowli has the highest average cost,it indicates customer engagement ig high.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes Highest-cost resaturant can target luxury dining customers.
# zomato can divide the customer segment into premium,mid-range and budgetsegment

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
df.groupby('Cuisines')['Rating'].mean().sort_values(ascending=False).head(5).plot(kind='bar')
plt.title('Average Rating per Cuisine')
plt.xlabel('Cuisine')
plt.ylabel('Average Rating')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I use bar chart to compare the numerical values of cuisines categories.to visualise the cuisines with highest average rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# European and medittersran cuisine have the highest average ratings.it shows strong customer service.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes Resataurants offering highly rated cuisines can be promoted more on the platform.
#
# Yes Restaurants serving cuisines with lower ratings may lose customer.If they fail to improve food quality or service.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
df.groupby('Cuisines')['Pictures'].mean().sort_values(ascending=False).head(5).plot(kind='bar')
plt.title('Average Pictures per Cuisine')
plt.xlabel('Cuisine')
plt.ylabel('Average Pictures')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used bar chart to compare the numerical values of categories.To viualise the cuisines with averge pictures per cuisines

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# North indian ,continental,chinese and italian have the highest average pictures.it shows good quality of services they are providing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes the more number of photos engage the customer and attract the cutomers.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
df.groupby('Restaurant')['Pictures'].mean().sort_values(ascending=False).head(5).plot(kind='bar')
plt.title('Average Pictures per Restaurant')
plt.xlabel('Restaurant')
plt.ylabel('Average Pictures')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i selected bar chart to compare the numerical values of categ

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# pourHouse7 restaurant has highest average number of pictures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes restaurants with more pictures tend to attract more customers, because people like to see food images before ordering.
#
# yes restaurants with fewer pictures can improve their profile by adding high-quality food images

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
df.groupby('Cuisines')['Cost'].mean().sort_values(ascending=False).head(5).plot(kind='bar')
plt.title('Average Cost of Restaurants by Cuisine')
plt.xlabel('Cuisine')
plt.ylabel('Average Cost')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used a Bar Chart because it helps compare average values across different restaurants.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Chinese and Asian cuisine have the highest average cost

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes Restaurants offering premium cuisines can target high-spending customers.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
df['Location'].value_counts().head(5).plot(kind='bar')
plt.title("Top 5 Locations with Most Restaurants")
plt.xlabel("Location")
plt.ylabel("Number of Restaurants")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected bar chart to show which location which has most reasturants

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# i found most the restaurant is in location hyderabad

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes i found very less restaurant in other location in hyderabad
# zomato need to focus more on other location to increase the sales and customer engagement.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
sns.scatterplot(x='Cost', y='Rating', data=df)
plt.title("Cost vs Rating")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected the scatter pot to show the relationship between the cost and rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Restaurant price range between 500 to 2000 had more number of ratings and restaurant with high price has less than average rating.Higher cost restaurant tend to recieve slightly less review.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes customer value quality and service more than price

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
df['Cuisines'].value_counts().head(5).plot(kind='barh')
plt.title("Top 5 Popular Cuisines")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used horizontal bar chart because it is effective for comparing categorical data with counts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# North indian ,chinese cuisines are most popular cuisines having highest sales counts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Restaurant should focus more on north indian and chinese to attract more customer.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.title('Correlation Heatmap')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i used heatmap to visualise the relationship between the multiple numerical data.to show the strength and direction of correlation between the variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# pictures and rating has a strong positive correlation,restaurant with more pictures tends

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used pairplot to visualise the relationship between the multiple numerical data variable and correlation between each variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution of numerical variables such as cot, rating,reviews,followers and picture

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# 1. Do Cost efects the ratings
# 2. Do restaurant with pictures get better ratings
# 3. Do different cuisines have different ratings

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# (Null hypothesis)Pictures do not effect ratings
# (Alternate Hypothesis)Picture affect rating

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import ttest_ind

with_pic = df[df['Pictures'] > 0]['Rating']
no_pic = df[df['Pictures'] == 0]['Rating']

t_stat, p_value = ttest_ind(with_pic, no_pic)

print("t-statistic:", t_stat)
print("p-value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I use independent two sample T-Test to obtain p-value

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Because we are comparing two groups .it shows our p-value is 1.9 which is  below 0.05 ,it's fail to reject null hypothesis

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# (Null hypothesis)Restaurants cost  effects rating
# (Alternate hypothesis)Restaurant cost does not affects rating

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

corr, p_value = pearsonr(df['Cost'], df['Rating'])

print("Correlation:", corr)
print("P-value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I used pearsonr correlation test to obtain P_value and for numerical data.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# To check does high cost restaurant effects rating
# To check does there is a linear relationship between Restaurant cost and ratings.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import f_oneway

top_cuisines = df['Cuisines'].value_counts().head(3).index
g1 = df[df['Cuisines']==top_cuisines[0]]['Rating']
g2 = df[df['Cuisines']==top_cuisines[1]]['Rating']
g3 = df[df['Cuisines']==top_cuisines[2]]['Rating']



f_stat, p_value = f_oneway(g1, g2, g3)
print('f-statistics',f_stat)
print("P-value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I used one-way Anova

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# i am comparing the average ratings across more than two cuisine  groups.Anova helps determine whether the mean ratings differ significantly among different cuisine.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

df['followers'].fillna(df['followers'].median(),inplace=True)
df.isnull().sum()

# %%
df.dropna()

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# I used fillna to fill  the NaN using median stats,
# then dropna method to drop all the unncecessary null values

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
sns.boxplot(df['Cost'])

# %%
Q1=df['Cost'].quantile(0.25)
Q3=df['Cost'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
print(lower_limit)
print(upper_limit)

# %%
df = df[(df['Cost']>=lower_limit) & (df['Cost']<=upper_limit)]

# %%
sns.boxplot(df['Cost'])

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# I use boxplot to visualise and detect the outliers,
# I IQR to check the outlier lower_limt and upper_limit then removed the outliers.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df['Restaurant']=le.fit_transform(df['Restaurant'])
df['Cuisines']=le.fit_transform(df['Cuisines'])
df['Location']=le.fit_transform(df['Location'])
df.head(3)

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# I used Label encoding technique to convert categorical text to numercial value,
# i used because ml algoritm understand only numerical data.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction
df[['Review']].head()

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text

df['clean_review'] = df['Review'].apply(clean_text)

# %%
import nltk
nltk.download('stopwords')
print("NLTK 'stopwords' corpus downloaded.")

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

df['clean_review'] = df['clean_review'].apply(
    lambda x: " ".join([word for word in x.split() if word not in stop_words])
)

# %%
from textblob import TextBlob

def get_sentiment(text):
    score = TextBlob(text).sentiment.polarity

    if score > 0:
        return 'Positive'
    elif score < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment'] = df['clean_review'].apply(get_sentiment)

# %%
df['sentiment'].value_counts()

# %%
sns.countplot(x='sentiment', data=df)
plt.title("Sentiment Distribution")
plt.show()

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
df.drop(columns=['Reviewer','Metadata','Restaurant','Review',],axis=1,inplace=True)
df['Cost_per_person'] = df['Cost']/2

# %%
df.isnull().sum()
df.dropna(inplace=True)
df.isnull().sum()

# %%
df.head()

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
x=df.drop(columns=['Rating'])
y=df['Rating']

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# I split the dataset into 80:20 for training and testing.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Convert text to numerical features
tfidf = TfidfVectorizer(max_features=5000)
X = tfidf.fit_transform(df['clean_review'])
y = df['sentiment']

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = LogisticRegression(class_weight='balanced')

model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

print(accuracy_score(y_test, y_pred))

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
#I used logistic regression model to perform sentiment analysis on the cleaned reviews.
#Text data was converted into numericak features using TF-IDF vectorization.
from sklearn.metrics import accuracy_score,classification_report
import matplotlib.pyplot as plt

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred))


# Plot the confusion matrix

plt.figure(figsize=(8, 6))
plt.bar(df['sentiment'].unique(),height=df['sentiment'].value_counts(),color=['red','blue','green'])
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.linear_model import LogisticRegression

cv_scores = cross_val_score(model, X, y, cv=5)

print("Cross Validation Scores:", cv_scores)
print("Average CV Score:", cv_scores.mean())
# Fit the Algorithm
LR=LogisticRegression(solver='liblinear', random_state=42,class_weight='balanced') # Specify a solver and random_state for reproducibility

# Define a valid parameter grid for LogisticRegression
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'] # 'l1' penalty requires 'liblinear' solver
}

grid = GridSearchCV(LR,param_grid,cv=5,scoring='accuracy')

grid.fit(X_train,y_train)

# Predict on the model
y_pred=grid.predict(X_test)
print("Best parameters for Logistic Regression:", grid.best_params_)
print("Tuned Logistic Regression Accuracy:", accuracy_score(y_test,y_pred))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# i have used gridsearchcv Hyperparameter to optomized the performance of model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# No changes in the model after tuning.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report
rf = RandomForestClassifier()

rf.fit(X_train,y_train)

pred = rf.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))
print('Classification',classification_report(y_test,pred))

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

cv_scores = cross_val_score(model, X, y, cv=5)


print("Cross Validation Scores:", cv_scores)
print("Average CV Score:", cv_scores.mean())
 #Fit the Algorithm
rf = RandomForestClassifier()

grid_param = {
    'n_estimators': [100,200],
    'max_depth': [10,20],
    'min_samples_split': [2,5],
    'min_samples_leaf': [1,2]
}

grid=GridSearchCV(rf,grid_param,cv=5,scoring='accuracy')

grid.fit(X_train,y_train)
#Predict on the model
y_pred=grid.predict(X_test)
print(accuracy_score(y_test,y_pred))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# i have used gridsearchcv Hyperparameter to optomized the performance of model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# yes before performing hyperparameter tuning model performance was 90 then after tuning the model optimized to 91.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,classification_report

model=MultinomialNB()

# Fit the Algorithm
model.fit(X_train, y_train)

# Predict on the model
y_pred=model.predict(X_test)

print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
from sklearn.metrics import accuracy_score, classification_report
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.naive_bayes import MultinomialNB

cv_scores = cross_val_score(model, X, y, cv=5)

print("Cross Validation Scores:", cv_scores)
print("Average CV Score:", cv_scores.mean())
# Fit the Algorithm
model = MultinomialNB()
# Define hyperparameters to tune for MultinomialNB (alpha is a common one)
grid_param={
    'alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]
}
grid=GridSearchCV(model,grid_param,cv=5,scoring='accuracy')

grid.fit(X_train,y_train)
# Predict on the model
print("Best Parameters:",grid.best_params_)
print("Best Score:",grid.best_score_)
y_pred=grid.predict(X_test)
print(accuracy_score(y_test,y_pred))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# yes before performing hyperparameter tuning model performance was 83 then after tuning the model optimized to 87.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# logistic regression model.model performance is 94 after tuning

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
import joblib
joblib.dump(grid,'sentiment_model.pkl')
joblib.dump(tfidf,'tfidf.pkl')

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
model = joblib.load("sentiment_model.pkl")
vectorizer = joblib.load("tfidf.pkl")

review = ["food was good and service was fast"]

review_vector = vectorizer.transform(review)

prediction = model.predict(review_vector)

print(prediction)

# %%
from google.colab import files

files.download("sentiment_model.pkl")
files.download("tfidf.pkl")

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Most restaurants have positive reviews
#
# North Indian cuisine is most popular
#
# Medium cost restaurants have highest ratings
#
# Some reviewers act like food critics

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
